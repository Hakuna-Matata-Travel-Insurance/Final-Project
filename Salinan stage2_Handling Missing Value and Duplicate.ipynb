# %% [markdown]
# Data Pre-Processing
#
# Handling Missing Value and Duplicate
#
# Data Source: Travel Insurance (https://www.kaggle.com/datasets/tejashvi14/travel-insurance-prediction-data/code)

# %%
#import library
import pandas as pd

# %%
#load data
df = pd.read_csv('/content/drive/MyDrive/Rakamin Academy/DS JAP/final project/TravelInsurancePrediction.csv')

# %% [markdown]
# # **Handling Missing Value**

# %%
#Checking Missing Value
df.isna().sum()
# Out:
# Unnamed: 0             0
# Age                    0
# Employment Type        0
# GraduateOrNot          0
# AnnualIncome           0
# FamilyMembers          0
# ChronicDiseases        0
# FrequentFlyer          0
# EverTravelledAbroad    0
# TravelInsurance        0
# dtype: int64

# %% [markdown]
# Code Result: There are no missing values in this data set

# %% [markdown]
# # **Handling Duplicated Data**

# %%
#Checking Duplicate Data
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Code Result: There are no data duplicate in this data set
